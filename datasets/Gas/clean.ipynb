# %% [markdown]
# # Gas transport dataset cleanup

# %%
from pathlib import Path

import pandas as pd
import yaml

# %%
data_dir = Path.cwd()
config = yaml.safe_load((data_dir / 'dataset.yaml').read_text())
raw_path = data_dir / 'Gas_permeability_solubility_diffusivity_wide.csv'
clean_path = data_dir / config['data_file']
smiles_col = config['smiles_column']

df = pd.read_csv(raw_path, low_memory=False)
df = df.drop_duplicates(subset=[smiles_col], keep="first")

star_count = df[smiles_col].str.count(r'\*')
df = df.loc[star_count.eq(2)].copy()

print(f'Input rows: {star_count.shape[0]}')
print(f'Removed rows by star count: {(~star_count.eq(2)).sum()}')
print(f'Rows after star-count filter: {len(df)}')
# Out:
# Input rows: 1049
# Removed rows by star count: 55
# Rows after star-count filter: 994

# %%
df.to_csv(clean_path, index=False)
df
# Out:
#                                           smiles_string  d_exp_CH4  d_exp_CO2  \
# 52                [*]/C(=C(/[*])c1ccc(CCCC)cc1)c1ccccc1        NaN        NaN
# 53    [*]/C(=C(/[*])c1ccc(S(=O)(=O)O)cc1)c1ccc(CCCC)cc1        NaN        NaN
# 54    [*]/C(=C(/[*])c1ccc(S(=O)(=O)O)cc1)c1ccc([Si](...        NaN        NaN
# 55    [*]/C(=C(/[*])c1ccc([Si](C(C)C)(C(C)C)C(C)C)cc...        NaN        NaN
# 56    [*]/C(=C(/[*])c1ccc([Si](C)(C)C)cc1)c1ccc(-c2c...        NaN        NaN
# ...                                                 ...        ...        ...
# 1042  [*]c1cccc2c(-n3c(=O)c4cc5oc6cc7c(cc6oc5cc4c3=O...        NaN        NaN
# 1043  [*]c1cncc(-c2ccc(Oc3ccc(C(c4ccc(Oc5ccc([*])cc5...        NaN        NaN
# 1044  [*]c1nc2cc3sc(-c4cc(OCCCCCCCCCC)c([*])cc4OCCCC...        NaN        NaN
# 1045  [*]c1nc2ccc(-c3ccc4[nH]c(-c5cc(Br)c([*])cc5Br)...        NaN        NaN
# 1046                          [*]c1nnc(C2CCC([*])CC2)o1        NaN        NaN
#
#       d_exp_H2  d_exp_He  d_exp_N2  d_exp_O2  d_sim_CH4  d_sim_CO2  d_sim_N2  \
# 52         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 53         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 54         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 55         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 56         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# ...        ...       ...       ...       ...        ...        ...       ...
# 1042       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 1043       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 1044       NaN       NaN       NaN       NaN        NaN  -6.141463       NaN
# 1045       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 1046       NaN       NaN       NaN       NaN        NaN        NaN       NaN
#
#       ...  s_exp_CH4  s_exp_CO2  s_exp_H2  s_exp_He  s_exp_N2  s_exp_O2  \
# 52    ...        NaN        NaN       NaN       NaN       NaN       NaN
# 53    ...        NaN        NaN       NaN       NaN       NaN       NaN
# 54    ...        NaN        NaN       NaN       NaN       NaN       NaN
# 55    ...        NaN        NaN       NaN       NaN       NaN       NaN
# 56    ...        NaN        NaN       NaN       NaN       NaN       NaN
# ...   ...        ...        ...       ...       ...       ...       ...
# 1042  ...        NaN        NaN       NaN       NaN       NaN       NaN
# 1043  ...        NaN        NaN       NaN       NaN       NaN       NaN
# 1044  ...        NaN        NaN       NaN       NaN       NaN       NaN
# 1045  ...        NaN        NaN       NaN       NaN       NaN       NaN
# 1046  ...        NaN        NaN       NaN       NaN       NaN       NaN
#
#       s_sim_CH4  s_sim_CO2  s_sim_N2  s_sim_O2
# 52          NaN        NaN       NaN       NaN
# 53          NaN        NaN       NaN       NaN
# 54          NaN        NaN       NaN       NaN
# 55          NaN        NaN       NaN       NaN
# 56          NaN        NaN       NaN       NaN
# ...         ...        ...       ...       ...
# 1042        NaN        NaN       NaN       NaN
# 1043        NaN        NaN       NaN       NaN
# 1044        NaN        NaN       NaN       NaN
# 1045        NaN        NaN       NaN       NaN
# 1046        NaN        NaN       NaN       NaN
#
# [994 rows x 31 columns]
